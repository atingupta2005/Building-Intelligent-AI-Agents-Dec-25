# %% [markdown]
# # Environment Validation Notebook
#
# This notebook validates that:
#
# - Python version is **3.11.x**
# - All critical LangChain ecosystem packages match expected versions
# - LangChain execution works end-to-end
# - Verbose callbacks work
# - Prompt + LLM pipeline runs successfully
#
# Run cells **top to bottom**.

# %%
pip install --upgrade pip
# Out:
# Requirement already satisfied: pip in c:\venv311\lib\site-packages (25.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install -r requirements.txt
# Out:
# Requirement already satisfied: langchain==1.2.0 in c:\venv311\lib\site-packages (from -r requirements.txt (line 10)) (1.2.0)
# Requirement already satisfied: langchain-core==1.2.2 in c:\venv311\lib\site-packages (from -r requirements.txt (line 11)) (1.2.2)
# Requirement already satisfied: langchain-community==0.4.1 in c:\venv311\lib\site-packages (from -r requirements.txt (line 12)) (0.4.1)
# Requirement already satisfied: langchain-openai==1.1.5 in c:\venv311\lib\site-packages (from -r requirements.txt (line 13)) (1.1.5)
# Requirement already satisfied: langchain-text-splitters==1.1.0 in c:\venv311\lib\site-packages (from -r requirements.txt (line 16)) (1.1.0)
# Requirement already satisfied: langgraph==1.0.5 in c:\venv311\lib\site-packages (from -r requirements.txt (line 22)) (1.0.5)
# Requirement already satisfied: langgraph-prebuilt==1.0.5 in c:\venv311\lib\site-packages (from -r requirements.txt (line 23)) (1.0.5)
# Requirement already satisfied: langgraph-checkpoint==3.0.1 in c:\venv311\lib\site-packages (from -r requirements.txt (line 24)) (3.0.1)
# Requirement already satisfied: openai==2.13.0 in c:\venv311\lib\site-packages (from -r requirements.txt (line 29)) (2.13.0)
# Requirement already satisfied: tiktoken==0.12.0 in c:\venv311\lib\site-packages (from -r requirements.txt (line 30)) (0.12.0)
# Requirement already satisfied: httpx==0.28.1 in c:\venv311\lib\site-packages (from -r requirements.txt (line 35)) (0.28.1)
# Requirement already satisfied: aiohttp==3.13.2 in c:\venv311\lib\site-packages (from -r requirements.txt (line 36)) (3.13.2)
# Requirement already satisfied: anyio==4.12.0 in c:\venv311\lib\site-packages (from -r requirements.txt (line 37)) (4.12.0)
# Requirement already satisfied: pydantic==2.12.5 in c:\venv311\lib\site-packages (from -r requirements.txt (line 42)) (2.12.5)
# Requirement already satisfied: pydantic-settings==2.12.0 in c:\venv311\lib\site-packages (from -r requirements.txt (line 43)) (2.12.0)
# Requirement already satisfied: typing_extensions==4.15.0 in c:\venv311\lib\site-packages (from -r requirements.txt (line 44)) (4.15.0)
# Requirement already satisfied: ddgs==9.10.0 in c:\venv311\lib\site-packages (from -r requirements.txt (line 49)) (9.10.0)
# Requirement already satisfied: requests==2.32.5 in c:\venv311\lib\site-packages (from -r requirements.txt (line 50)) (2.32.5)
# Requirement already satisfied: beautifulsoup4==4.14.3 in c:\venv311\lib\site-packages (from -r requirements.txt (line 51)) (4.14.3)
# Requirement already satisfied: ipykernel==7.1.0 in c:\venv311\lib\site-packages (from -r requirements.txt (line 56)) (7.1.0)
# Requirement already satisfied: ipython==9.8.0 in c:\venv311\lib\site-packages (from -r requirements.txt (line 57)) (9.8.0)
# Requirement already satisfied: jupyterlab==4.5.1 in c:\venv311\lib\site-packages (from -r requirements.txt (line 58)) (4.5.1)
# Requirement already satisfied: python-dotenv==1.2.1 in c:\venv311\lib\site-packages (from -r requirements.txt (line 63)) (1.2.1)
# Requirement already satisfied: tqdm==4.67.1 in c:\venv311\lib\site-packages (from -r requirements.txt (line 64)) (4.67.1)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\venv311\lib\site-packages (from langchain-core==1.2.2->-r requirements.txt (line 11)) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in c:\venv311\lib\site-packages (from langchain-core==1.2.2->-r requirements.txt (line 11)) (0.5.0)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in c:\venv311\lib\site-packages (from langchain-core==1.2.2->-r requirements.txt (line 11)) (25.0)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in c:\venv311\lib\site-packages (from langchain-core==1.2.2->-r requirements.txt (line 11)) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\venv311\lib\site-packages (from langchain-core==1.2.2->-r requirements.txt (line 11)) (9.1.2)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in c:\venv311\lib\site-packages (from langchain-core==1.2.2->-r requirements.txt (line 11)) (0.12.0)
# Requirement already satisfied: langgraph-sdk<0.4.0,>=0.3.0 in c:\venv311\lib\site-packages (from langgraph==1.0.5->-r requirements.txt (line 22)) (0.3.0)
# Requirement already satisfied: xxhash>=3.5.0 in c:\venv311\lib\site-packages (from langgraph==1.0.5->-r requirements.txt (line 22)) (3.6.0)
# Requirement already satisfied: ormsgpack>=1.12.0 in c:\venv311\lib\site-packages (from langgraph-checkpoint==3.0.1->-r requirements.txt (line 24)) (1.12.1)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\venv311\lib\site-packages (from pydantic==2.12.5->-r requirements.txt (line 42)) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\venv311\lib\site-packages (from pydantic==2.12.5->-r requirements.txt (line 42)) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\venv311\lib\site-packages (from pydantic==2.12.5->-r requirements.txt (line 42)) (0.4.2)
# Requirement already satisfied: langchain-classic<2.0.0,>=1.0.0 in c:\venv311\lib\site-packages (from langchain-community==0.4.1->-r requirements.txt (line 12)) (1.0.0)
# Requirement already satisfied: SQLAlchemy<3.0.0,>=1.4.0 in c:\venv311\lib\site-packages (from langchain-community==0.4.1->-r requirements.txt (line 12)) (2.0.45)
# Requirement already satisfied: dataclasses-json<0.7.0,>=0.6.7 in c:\venv311\lib\site-packages (from langchain-community==0.4.1->-r requirements.txt (line 12)) (0.6.7)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in c:\venv311\lib\site-packages (from langchain-community==0.4.1->-r requirements.txt (line 12)) (0.4.3)
# Requirement already satisfied: numpy>=1.26.2 in c:\venv311\lib\site-packages (from langchain-community==0.4.1->-r requirements.txt (line 12)) (2.3.5)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in c:\venv311\lib\site-packages (from aiohttp==3.13.2->-r requirements.txt (line 36)) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in c:\venv311\lib\site-packages (from aiohttp==3.13.2->-r requirements.txt (line 36)) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\venv311\lib\site-packages (from aiohttp==3.13.2->-r requirements.txt (line 36)) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\venv311\lib\site-packages (from aiohttp==3.13.2->-r requirements.txt (line 36)) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\venv311\lib\site-packages (from aiohttp==3.13.2->-r requirements.txt (line 36)) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in c:\venv311\lib\site-packages (from aiohttp==3.13.2->-r requirements.txt (line 36)) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\venv311\lib\site-packages (from aiohttp==3.13.2->-r requirements.txt (line 36)) (1.22.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\venv311\lib\site-packages (from requests==2.32.5->-r requirements.txt (line 50)) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\venv311\lib\site-packages (from requests==2.32.5->-r requirements.txt (line 50)) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\venv311\lib\site-packages (from requests==2.32.5->-r requirements.txt (line 50)) (2.6.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\venv311\lib\site-packages (from requests==2.32.5->-r requirements.txt (line 50)) (2025.11.12)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\venv311\lib\site-packages (from openai==2.13.0->-r requirements.txt (line 29)) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.10.0 in c:\venv311\lib\site-packages (from openai==2.13.0->-r requirements.txt (line 29)) (0.12.0)
# Requirement already satisfied: sniffio in c:\venv311\lib\site-packages (from openai==2.13.0->-r requirements.txt (line 29)) (1.3.1)
# Requirement already satisfied: regex>=2022.1.18 in c:\venv311\lib\site-packages (from tiktoken==0.12.0->-r requirements.txt (line 30)) (2025.11.3)
# Requirement already satisfied: httpcore==1.* in c:\venv311\lib\site-packages (from httpx==0.28.1->-r requirements.txt (line 35)) (1.0.9)
# Requirement already satisfied: click>=8.1.8 in c:\venv311\lib\site-packages (from ddgs==9.10.0->-r requirements.txt (line 49)) (8.3.1)
# Requirement already satisfied: primp>=0.15.0 in c:\venv311\lib\site-packages (from ddgs==9.10.0->-r requirements.txt (line 49)) (0.15.0)
# Requirement already satisfied: lxml>=4.9.4 in c:\venv311\lib\site-packages (from ddgs==9.10.0->-r requirements.txt (line 49)) (6.0.2)
# Requirement already satisfied: fake-useragent>=2.2.0 in c:\venv311\lib\site-packages (from ddgs==9.10.0->-r requirements.txt (line 49)) (2.2.0)
# Requirement already satisfied: soupsieve>=1.6.1 in c:\venv311\lib\site-packages (from beautifulsoup4==4.14.3->-r requirements.txt (line 51)) (2.8)
# Requirement already satisfied: comm>=0.1.1 in c:\venv311\lib\site-packages (from ipykernel==7.1.0->-r requirements.txt (line 56)) (0.2.3)
# Requirement already satisfied: debugpy>=1.6.5 in c:\venv311\lib\site-packages (from ipykernel==7.1.0->-r requirements.txt (line 56)) (1.8.19)
# Requirement already satisfied: jupyter-client>=8.0.0 in c:\venv311\lib\site-packages (from ipykernel==7.1.0->-r requirements.txt (line 56)) (8.7.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\venv311\lib\site-packages (from ipykernel==7.1.0->-r requirements.txt (line 56)) (5.9.1)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\venv311\lib\site-packages (from ipykernel==7.1.0->-r requirements.txt (line 56)) (0.2.1)
# Requirement already satisfied: nest-asyncio>=1.4 in c:\venv311\lib\site-packages (from ipykernel==7.1.0->-r requirements.txt (line 56)) (1.6.0)
# Requirement already satisfied: psutil>=5.7 in c:\venv311\lib\site-packages (from ipykernel==7.1.0->-r requirements.txt (line 56)) (7.1.3)
# Requirement already satisfied: pyzmq>=25 in c:\venv311\lib\site-packages (from ipykernel==7.1.0->-r requirements.txt (line 56)) (27.1.0)
# Requirement already satisfied: tornado>=6.2 in c:\venv311\lib\site-packages (from ipykernel==7.1.0->-r requirements.txt (line 56)) (6.5.4)
# Requirement already satisfied: traitlets>=5.4.0 in c:\venv311\lib\site-packages (from ipykernel==7.1.0->-r requirements.txt (line 56)) (5.14.3)
# Requirement already satisfied: colorama>=0.4.4 in c:\venv311\lib\site-packages (from ipython==9.8.0->-r requirements.txt (line 57)) (0.4.6)
# Requirement already satisfied: decorator>=4.3.2 in c:\venv311\lib\site-packages (from ipython==9.8.0->-r requirements.txt (line 57)) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers>=1.0.0 in c:\venv311\lib\site-packages (from ipython==9.8.0->-r requirements.txt (line 57)) (1.1.1)
# Requirement already satisfied: jedi>=0.18.1 in c:\venv311\lib\site-packages (from ipython==9.8.0->-r requirements.txt (line 57)) (0.19.2)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in c:\venv311\lib\site-packages (from ipython==9.8.0->-r requirements.txt (line 57)) (3.0.52)
# Requirement already satisfied: pygments>=2.11.0 in c:\venv311\lib\site-packages (from ipython==9.8.0->-r requirements.txt (line 57)) (2.19.2)
# Requirement already satisfied: stack_data>=0.6.0 in c:\venv311\lib\site-packages (from ipython==9.8.0->-r requirements.txt (line 57)) (0.6.3)
# Requirement already satisfied: async-lru>=1.0.0 in c:\venv311\lib\site-packages (from jupyterlab==4.5.1->-r requirements.txt (line 58)) (2.0.5)
# Requirement already satisfied: jinja2>=3.0.3 in c:\venv311\lib\site-packages (from jupyterlab==4.5.1->-r requirements.txt (line 58)) (3.1.6)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in c:\venv311\lib\site-packages (from jupyterlab==4.5.1->-r requirements.txt (line 58)) (2.3.0)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in c:\venv311\lib\site-packages (from jupyterlab==4.5.1->-r requirements.txt (line 58)) (2.17.0)
# Requirement already satisfied: jupyterlab-server<3,>=2.28.0 in c:\venv311\lib\site-packages (from jupyterlab==4.5.1->-r requirements.txt (line 58)) (2.28.0)
# Requirement already satisfied: notebook-shim>=0.2 in c:\venv311\lib\site-packages (from jupyterlab==4.5.1->-r requirements.txt (line 58)) (0.2.4)
# Requirement already satisfied: setuptools>=41.1.0 in c:\venv311\lib\site-packages (from jupyterlab==4.5.1->-r requirements.txt (line 58)) (65.5.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\venv311\lib\site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community==0.4.1->-r requirements.txt (line 12)) (3.26.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in c:\venv311\lib\site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community==0.4.1->-r requirements.txt (line 12)) (0.9.0)
# Requirement already satisfied: h11>=0.16 in c:\venv311\lib\site-packages (from httpcore==1.*->httpx==0.28.1->-r requirements.txt (line 35)) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\venv311\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core==1.2.2->-r requirements.txt (line 11)) (3.0.0)
# Requirement already satisfied: argon2-cffi>=21.1 in c:\venv311\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab==4.5.1->-r requirements.txt (line 58)) (25.1.0)
# Requirement already satisfied: jupyter-events>=0.11.0 in c:\venv311\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab==4.5.1->-r requirements.txt (line 58)) (0.12.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in c:\venv311\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab==4.5.1->-r requirements.txt (line 58)) (0.5.3)
# Requirement already satisfied: nbconvert>=6.4.4 in c:\venv311\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab==4.5.1->-r requirements.txt (line 58)) (7.16.6)
# Requirement already satisfied: nbformat>=5.3.0 in c:\venv311\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab==4.5.1->-r requirements.txt (line 58)) (5.10.4)
# Requirement already satisfied: overrides>=5.0 in c:\venv311\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab==4.5.1->-r requirements.txt (line 58)) (7.7.0)
# Requirement already satisfied: prometheus-client>=0.9 in c:\venv311\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab==4.5.1->-r requirements.txt (line 58)) (0.23.1)
# Requirement already satisfied: pywinpty>=2.0.1 in c:\venv311\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab==4.5.1->-r requirements.txt (line 58)) (3.0.2)
# Requirement already satisfied: send2trash>=1.8.2 in c:\venv311\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab==4.5.1->-r requirements.txt (line 58)) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in c:\venv311\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab==4.5.1->-r requirements.txt (line 58)) (0.18.1)
# Requirement already satisfied: websocket-client>=1.7 in c:\venv311\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab==4.5.1->-r requirements.txt (line 58)) (1.9.0)
# Requirement already satisfied: babel>=2.10 in c:\venv311\lib\site-packages (from jupyterlab-server<3,>=2.28.0->jupyterlab==4.5.1->-r requirements.txt (line 58)) (2.17.0)
# Requirement already satisfied: json5>=0.9.0 in c:\venv311\lib\site-packages (from jupyterlab-server<3,>=2.28.0->jupyterlab==4.5.1->-r requirements.txt (line 58)) (0.12.1)
# Requirement already satisfied: jsonschema>=4.18.0 in c:\venv311\lib\site-packages (from jupyterlab-server<3,>=2.28.0->jupyterlab==4.5.1->-r requirements.txt (line 58)) (4.25.1)
# Requirement already satisfied: orjson>=3.10.1 in c:\venv311\lib\site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph==1.0.5->-r requirements.txt (line 22)) (3.11.5)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\venv311\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core==1.2.2->-r requirements.txt (line 11)) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in c:\venv311\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core==1.2.2->-r requirements.txt (line 11)) (0.25.0)
# Requirement already satisfied: wcwidth in c:\venv311\lib\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython==9.8.0->-r requirements.txt (line 57)) (0.2.14)
# Requirement already satisfied: greenlet>=1 in c:\venv311\lib\site-packages (from SQLAlchemy<3.0.0,>=1.4.0->langchain-community==0.4.1->-r requirements.txt (line 12)) (3.3.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\venv311\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7.0,>=0.6.7->langchain-community==0.4.1->-r requirements.txt (line 12)) (1.1.0)
# Requirement already satisfied: argon2-cffi-bindings in c:\venv311\lib\site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab==4.5.1->-r requirements.txt (line 58)) (25.1.0)
# Requirement already satisfied: brotli in c:\venv311\lib\site-packages (from httpx[brotli,http2,socks]>=0.28.1->ddgs==9.10.0->-r requirements.txt (line 49)) (1.2.0)
# Requirement already satisfied: h2<5,>=3 in c:\venv311\lib\site-packages (from httpx[brotli,http2,socks]>=0.28.1->ddgs==9.10.0->-r requirements.txt (line 49)) (4.3.0)
# Requirement already satisfied: socksio==1.* in c:\venv311\lib\site-packages (from httpx[brotli,http2,socks]>=0.28.1->ddgs==9.10.0->-r requirements.txt (line 49)) (1.0.0)
# Requirement already satisfied: hyperframe<7,>=6.1 in c:\venv311\lib\site-packages (from h2<5,>=3->httpx[brotli,http2,socks]>=0.28.1->ddgs==9.10.0->-r requirements.txt (line 49)) (6.1.0)
# Requirement already satisfied: hpack<5,>=4.1 in c:\venv311\lib\site-packages (from h2<5,>=3->httpx[brotli,http2,socks]>=0.28.1->ddgs==9.10.0->-r requirements.txt (line 49)) (4.1.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\venv311\lib\site-packages (from jedi>=0.18.1->ipython==9.8.0->-r requirements.txt (line 57)) (0.8.5)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\venv311\lib\site-packages (from jinja2>=3.0.3->jupyterlab==4.5.1->-r requirements.txt (line 58)) (3.0.3)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\venv311\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->jupyterlab==4.5.1->-r requirements.txt (line 58)) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\venv311\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->jupyterlab==4.5.1->-r requirements.txt (line 58)) (0.37.0)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\venv311\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->jupyterlab==4.5.1->-r requirements.txt (line 58)) (0.30.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\venv311\lib\site-packages (from jupyter-client>=8.0.0->ipykernel==7.1.0->-r requirements.txt (line 56)) (2.9.0.post0)
# Requirement already satisfied: platformdirs>=2.5 in c:\venv311\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel==7.1.0->-r requirements.txt (line 56)) (4.5.1)
# Requirement already satisfied: python-json-logger>=2.0.4 in c:\venv311\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab==4.5.1->-r requirements.txt (line 58)) (4.0.0)
# Requirement already satisfied: rfc3339-validator in c:\venv311\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab==4.5.1->-r requirements.txt (line 58)) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in c:\venv311\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab==4.5.1->-r requirements.txt (line 58)) (0.1.1)
# Requirement already satisfied: fqdn in c:\venv311\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab==4.5.1->-r requirements.txt (line 58)) (1.5.1)
# Requirement already satisfied: isoduration in c:\venv311\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab==4.5.1->-r requirements.txt (line 58)) (20.11.0)
# Requirement already satisfied: rfc3987-syntax>=1.1.0 in c:\venv311\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab==4.5.1->-r requirements.txt (line 58)) (1.1.0)
# Requirement already satisfied: uri-template in c:\venv311\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab==4.5.1->-r requirements.txt (line 58)) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in c:\venv311\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab==4.5.1->-r requirements.txt (line 58)) (25.10.0)
# Requirement already satisfied: bleach!=5.0.0 in c:\venv311\lib\site-packages (from bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab==4.5.1->-r requirements.txt (line 58)) (6.3.0)
# Requirement already satisfied: defusedxml in c:\venv311\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab==4.5.1->-r requirements.txt (line 58)) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in c:\venv311\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab==4.5.1->-r requirements.txt (line 58)) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in c:\venv311\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab==4.5.1->-r requirements.txt (line 58)) (3.1.4)
# Requirement already satisfied: nbclient>=0.5.0 in c:\venv311\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab==4.5.1->-r requirements.txt (line 58)) (0.10.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\venv311\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab==4.5.1->-r requirements.txt (line 58)) (1.5.1)
# Requirement already satisfied: webencodings in c:\venv311\lib\site-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab==4.5.1->-r requirements.txt (line 58)) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in c:\venv311\lib\site-packages (from bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab==4.5.1->-r requirements.txt (line 58)) (1.4.0)
# Requirement already satisfied: fastjsonschema>=2.15 in c:\venv311\lib\site-packages (from nbformat>=5.3.0->jupyter-server<3,>=2.4.0->jupyterlab==4.5.1->-r requirements.txt (line 58)) (2.21.2)
# Requirement already satisfied: six>=1.5 in c:\venv311\lib\site-packages (from python-dateutil>=2.8.2->jupyter-client>=8.0.0->ipykernel==7.1.0->-r requirements.txt (line 56)) (1.17.0)
# Requirement already satisfied: lark>=1.2.2 in c:\venv311\lib\site-packages (from rfc3987-syntax>=1.1.0->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab==4.5.1->-r requirements.txt (line 58)) (1.3.1)
# Requirement already satisfied: executing>=1.2.0 in c:\venv311\lib\site-packages (from stack_data>=0.6.0->ipython==9.8.0->-r requirements.txt (line 57)) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in c:\venv311\lib\site-packages (from stack_data>=0.6.0->ipython==9.8.0->-r requirements.txt (line 57)) (3.0.1)
# Requirement already satisfied: pure-eval in c:\venv311\lib\site-packages (from stack_data>=0.6.0->ipython==9.8.0->-r requirements.txt (line 57)) (0.2.3)
# Requirement already satisfied: cffi>=1.0.1 in c:\venv311\lib\site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab==4.5.1->-r requirements.txt (line 58)) (2.0.0)
# Requirement already satisfied: pycparser in c:\venv311\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab==4.5.1->-r requirements.txt (line 58)) (2.23)
# Requirement already satisfied: arrow>=0.15.0 in c:\venv311\lib\site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab==4.5.1->-r requirements.txt (line 58)) (1.4.0)
# Requirement already satisfied: tzdata in c:\venv311\lib\site-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab==4.5.1->-r requirements.txt (line 58)) (2025.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
import sys

print("Python version:", sys.version)

assert sys.version.startswith("3.11"), "❌ Python 3.11.x is required"
print("✅ Python version OK")
# Out:
# Python version: 3.11.0 (main, Oct 24 2022, 18:26:48) [MSC v.1933 64 bit (AMD64)]
# ✅ Python version OK

# %%
import importlib.metadata as md

EXPECTED_VERSIONS = {
    "langchain": "1.2.0",
    "langchain-core": "1.2.2",
    "langchain-community": "0.4.1",
    "langchain-openai": "1.1.5",
    "langgraph": "1.0.5",
    "openai": "2.13.0",
    "pydantic": "2.12.5",
    "typing-extensions": "4.15.0",
}

# %%
errors = False

for pkg, expected in EXPECTED_VERSIONS.items():
    installed = md.version(pkg)
    print(f"{pkg:25} installed={installed} expected={expected}")
    if installed != expected:
        errors = True
# Out:
# langchain                 installed=1.2.0 expected=1.2.0
# langchain-core            installed=1.2.2 expected=1.2.2
# langchain-community       installed=0.4.1 expected=0.4.1
# langchain-openai          installed=1.1.5 expected=1.1.5
# langgraph                 installed=1.0.5 expected=1.0.5
# openai                    installed=2.13.0 expected=2.13.0
# pydantic                  installed=2.12.5 expected=2.12.5
# typing-extensions         installed=4.15.0 expected=4.15.0

# %%
assert not errors, "❌ Version mismatch detected"
print("✅ All critical package versions match exactly")
# Out:
# ✅ All critical package versions match exactly

# %%
from langchain_core.prompts import ChatPromptTemplate
from langchain_openai import ChatOpenAI
from langchain_core.output_parsers import StrOutputParser
from langchain_core.callbacks import StdOutCallbackHandler

print("✅ Core LangChain imports successful")
# Out:
# ✅ Core LangChain imports successful

# %%
from langchain_core.prompts import ChatPromptTemplate

prompt_template = ChatPromptTemplate.from_template("""
You are an expert web researcher. Your goal is to provide a comprehensive answer.

Question:
{input}

Final Answer:
""")

# %%
import os
from dotenv import load_dotenv

# Load the API key from the .env file
dotenv_path = os.path.expanduser("~/dev.env")
load_dotenv(dotenv_path, override=True)

print("Dependencies installed and environment loaded.")
# Out:
# Dependencies installed and environment loaded.

# %%
from langchain_openai import ChatOpenAI

llm = ChatOpenAI(
    model="gpt-4o-mini",
    temperature=0
)

print("✅ LLM initialized")
# Out:
# ✅ LLM initialized

# %%
from langchain_core.output_parsers import StrOutputParser
from langchain_core.callbacks import StdOutCallbackHandler

callbacks = [StdOutCallbackHandler()]

chain = (
    prompt_template
    | llm.with_config({"callbacks": callbacks})
    | StrOutputParser()
)

print("✅ LangChain pipeline constructed")
# Out:
# ✅ LangChain pipeline constructed

# %%
from IPython.display import display, Markdown

topic = "Explain why LangChain moved agent execution to LangGraph"

response = chain.invoke({"input": topic})

print("\n--- Final Output (Markdown) ---")
display(Markdown(response))
# Out:
# --- Final Output (Markdown) ---
# LangChain's decision to move agent execution to LangGraph is rooted in several strategic and technical considerations aimed at enhancing the functionality, efficiency, and scalability of their framework for building applications powered by language models. Here are the key reasons for this transition:
#
# 1. **Improved Modularity**: By integrating agent execution into LangGraph, LangChain can offer a more modular architecture. This allows developers to build and customize their applications more easily, as they can leverage the graph structure to connect various components and functionalities without being tightly coupled.
#
# 2. **Enhanced Performance**: LangGraph is designed to optimize the execution of complex workflows. By moving agent execution to this framework, LangChain can take advantage of more efficient data handling and processing capabilities, leading to faster response times and improved overall performance of applications.
#
# 3. **Better Visualization and Debugging**: LangGraph provides a visual representation of the execution flow, making it easier for developers to understand and debug their applications. This transparency is crucial for identifying bottlenecks or issues in the agent's decision-making process, ultimately leading to more robust applications.
#
# 4. **Scalability**: As applications grow in complexity, the need for a scalable solution becomes paramount. LangGraph is built to handle larger and more intricate workflows, allowing LangChain to support more sophisticated use cases without compromising performance or reliability.
#
# 5. **Integration with Other Tools**: LangGraph facilitates better integration with other tools and libraries within the LangChain ecosystem. This interoperability allows developers to leverage existing resources and functionalities, streamlining the development process and enhancing the capabilities of their applications.
#
# 6. **Support for Advanced Features**: The move to LangGraph enables LangChain to implement advanced features such as dynamic agent behavior, real-time updates, and more complex decision-making processes. This flexibility is essential for creating applications that can adapt to changing inputs and user needs.
#
# 7. **Community and Ecosystem Growth**: By adopting LangGraph for agent execution, LangChain can foster a more vibrant community around its framework. Developers can contribute to and build upon the graph-based architecture, leading to a richer ecosystem of tools, libraries, and shared knowledge.
#
# In summary, the transition of agent execution to LangGraph represents a strategic enhancement for LangChain, focusing on modularity, performance, scalability, and community engagement. This move positions LangChain to better meet the evolving needs of developers and users in the rapidly advancing field of language model applications.

# %%
pip freeze | sort
# Out:
# aiohappyeyeballs==2.6.1
# aiohttp==3.13.2
# aiosignal==1.4.0
# aiosqlite==0.22.0
# annotated-types==0.7.0
# anyio==4.12.0
# argon2-cffi-bindings==25.1.0
# argon2-cffi==25.1.0
# arrow==1.4.0
# asttokens==3.0.1
# async-lru==2.0.5
# attrs==25.4.0
# babel==2.17.0
# beautifulsoup4==4.14.3
# bleach==6.3.0
# brotli==1.2.0
# cachetools==6.2.4
# certifi==2025.11.12
# cffi==2.0.0
# charset-normalizer==3.4.4
# click==8.3.1
# colorama==0.4.6
# comm==0.2.3
# dataclasses-json==0.6.7
# ddgs==9.10.0
# debugpy==1.8.19
# decorator==5.2.1
# defusedxml==0.7.1
# distro==1.9.0
# executing==2.2.1
# fake-useragent==2.2.0
# fastjsonschema==2.21.2
# filetype==1.2.0
# fqdn==1.5.1
# frozenlist==1.8.0
# google-auth==2.45.0
# google-genai==1.56.0
# greenlet==3.3.0
# h11==0.16.0
# h2==4.3.0
# hpack==4.1.0
# httpcore==1.0.9
# httpx-sse==0.4.3
# httpx==0.28.1
# hyperframe==6.1.0
# idna==3.11
# ipykernel==7.1.0
# ipython_pygments_lexers==1.1.1
# ipython==9.8.0
# ipywidgets==8.1.8
# isoduration==20.11.0
# jedi==0.19.2
# Jinja2==3.1.6
# jiter==0.12.0
# json5==0.12.1
# jsonpatch==1.33
# jsonpointer==3.0.0
# jsonschema-specifications==2025.9.1
# jsonschema==4.25.1
# jupyter-console==6.6.3
# jupyter-events==0.12.0
# jupyter-lsp==2.3.0
# jupyter_client==8.7.0
# jupyter_core==5.9.1
# jupyter_server_terminals==0.5.3
# jupyter_server==2.17.0
# jupyter==1.1.1
# jupyterlab_pygments==0.3.0
# jupyterlab_server==2.28.0
# jupyterlab_widgets==3.0.16
# jupyterlab==4.5.1
# langchain-classic==1.0.0
# langchain-community==0.4.1
# langchain-core==1.2.2
# langchain-google-genai==4.1.1
# langchain-openai==1.1.5
# langchain-text-splitters==1.1.0
# langchain==1.2.0
# langgraph-checkpoint-sqlite==3.0.1
# langgraph-checkpoint==3.0.1
# langgraph-prebuilt==1.0.5
# langgraph-sdk==0.3.0
# langgraph==1.0.5
# langsmith==0.5.0
# lark==1.3.1
# lxml==6.0.2
# MarkupSafe==3.0.3
# marshmallow==3.26.1
# matplotlib-inline==0.2.1
# mistune==3.1.4
# multidict==6.7.0
# mypy_extensions==1.1.0
# nbclient==0.10.2
# nbconvert==7.16.6
# nbformat==5.10.4
# nest-asyncio==1.6.0
# notebook_shim==0.2.4
# notebook==7.5.1
# numpy==2.3.5
# openai==2.13.0
# orjson==3.11.5
# ormsgpack==1.12.1
# overrides==7.7.0
# packaging==25.0
# pandocfilters==1.5.1
# parso==0.8.5
# platformdirs==4.5.1
# primp==0.15.0
# prometheus_client==0.23.1
# prompt_toolkit==3.0.52
# propcache==0.4.1
# psutil==7.1.3
# pure_eval==0.2.3
# pyasn1_modules==0.4.2
# pyasn1==0.6.1
# pycparser==2.23
# pydantic-settings==2.12.0
# pydantic_core==2.41.5
# pydantic==2.12.5
# Pygments==2.19.2
# python-dateutil==2.9.0.post0
# python-dotenv==1.2.1
# python-json-logger==4.0.0
# pywinpty==3.0.2
# PyYAML==6.0.3
# pyzmq==27.1.0
# referencing==0.37.0
# regex==2025.11.3
# requests-toolbelt==1.0.0
# requests==2.32.5
# rfc3339-validator==0.1.4
# rfc3986-validator==0.1.1
# rfc3987-syntax==1.1.0
# rpds-py==0.30.0
# rsa==4.9.1
# Send2Trash==1.8.3
# six==1.17.0
# sniffio==1.3.1
# socksio==1.0.0
# soupsieve==2.8
# SQLAlchemy==2.0.45
# sqlite-vec==0.1.6
# stack-data==0.6.3
# tenacity==9.1.2
# terminado==0.18.1
# tiktoken==0.12.0
# tinycss2==1.4.0
# tornado==6.5.4
# tqdm==4.67.1
# traitlets==5.14.3
# typing-inspect==0.9.0
# typing-inspection==0.4.2
# typing_extensions==4.15.0
# tzdata==2025.3
# uri-template==1.3.0
# urllib3==2.6.2
# uuid_utils==0.12.0
# wcwidth==0.2.14
# webcolors==25.10.0
# webencodings==0.5.1
# websocket-client==1.9.0
# websockets==15.0.1
# widgetsnbextension==4.0.15
# xxhash==3.6.0
# yarl==1.22.0
# zstandard==0.25.0
# Note: you may need to restart the kernel to use updated packages.
